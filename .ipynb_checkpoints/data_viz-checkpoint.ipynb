# %% [markdown]
# # Matplotlib-Data-VIz

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\EDA\Matplotlib-Data-VIz\sales_data.csv")

# %%
df.head()
# Out:
#   Product_ID Product_Name     Category  Sales_Amount  Quantity_Sold  \
# 0       P001       Laptop  Electronics          1500             10
# 1       P002   Headphones  Accessories           200             50
# 2       P003   Smartphone  Electronics          1200             20
# 3       P004       Tablet  Electronics           800             15
# 4       P005   Smartwatch    Wearables           300             25
#
#    Sales_Date
# 0  2024-08-01
# 1  2024-08-02
# 2  2024-08-03
# 3  2024-08-04
# 4  2024-08-05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product_ID     5 non-null      object
#  1   Product_Name   5 non-null      object
#  2   Category       5 non-null      object
#  3   Sales_Amount   5 non-null      int64
#  4   Quantity_Sold  5 non-null      int64
#  5   Sales_Date     5 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 372.0+ bytes

# %% [markdown]
# ### Bar Plot

# %%
plt.figure(figsize=(12,6))
plt.bar(df['Sales_Date'],df['Sales_Amount'])
plt.xlabel("Sales Date")
plt.ylabel("Sales Amount")
plt.title("Sales By Date")
plt.show()
